# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/process_classification_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Type  Air temperature [K]  Process temperature [K]  \
# 0           0     1            -0.948880                -0.945448
# 1           1     0            -0.898767                -0.877932
# 2           2     0            -0.948880                -1.012964
# 3           3     0            -0.898767                -0.945448
# 4           4     0            -0.898767                -0.877932
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure
# 0                0.274814     0.228446        -1.699001                0
# 1               -0.827242     0.621715        -1.651815                0
# 2               -0.133640     0.970039        -1.620357                0
# 3               -0.634575    -0.142350        -1.588900                0
# 4               -0.827242    -0.086169        -1.557442                0

# %%
df = df.iloc[0:,1:]

# %%
df.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     1            -0.948880                -0.945448                0.274814
# 1     0            -0.898767                -0.877932               -0.827242
# 2     0            -0.948880                -1.012964               -0.133640
# 3     0            -0.898767                -0.945448               -0.634575
# 4     0            -0.898767                -0.877932               -0.827242
#
#    Torque [Nm]  Tool wear [min]  Machine failure
# 0     0.228446        -1.699001                0
# 1     0.621715        -1.651815                0
# 2     0.970039        -1.620357                0
# 3    -0.142350        -1.588900                0
# 4    -0.086169        -1.557442                0

# %%
X = df.drop(columns=['Machine failure'],axis=1)

# %%
X.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     1            -0.948880                -0.945448                0.274814
# 1     0            -0.898767                -0.877932               -0.827242
# 2     0            -0.948880                -1.012964               -0.133640
# 3     0            -0.898767                -0.945448               -0.634575
# 4     0            -0.898767                -0.877932               -0.827242
#
#    Torque [Nm]  Tool wear [min]
# 0     0.228446        -1.699001
# 1     0.621715        -1.651815
# 2     0.970039        -1.620357
# 3    -0.142350        -1.588900
# 4    -0.086169        -1.557442

# %%
y = df['Machine failure']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Machine failure, dtype: int64

# %%
X.shape
# Out:
# (9535, 6)

# %%
y.shape
# Out:
# (9535,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10,stratify=y)

# %%
print("X_train = ",X_train.shape)
print("X_test = ",X_test.shape)
print("y_train = ",y_train.shape)
print("y_test = ",y_test.shape)
# Out:
# X_train =  (7628, 6)
# X_test =  (1907, 6)
# y_train =  (7628,)
# y_test =  (1907,)

# %%
print(y_train.value_counts())
# Out:
# Machine failure
# 0    7418
# 1     210
# Name: count, dtype: int64

# %%
print(y_test.value_counts())
# Out:
# Machine failure
# 0    1854
# 1      53
# Name: count, dtype: int64

# %%
X_train['Air temperature [K]']
# Out:
# 4565    1.807356
# 5781    0.504408
# 3479    1.155882
# 8587   -1.399901
# 4442    1.657016
#           ...
# 2057   -0.247293
# 9301   -0.748426
# 3414    0.905315
# 3609    1.205996
# 2982    0.053388
# Name: Air temperature [K], Length: 7628, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.intercept_
# Out:
# array([-5.27133539])

# %%
model.coef_
# Out:
# array([[-0.33469577,  1.7850361 , -1.18594783, -0.39456696,  1.32231424,
#          0.97852301]])

# %%
train_acc = model.score(X_train,y_train)

# %%
train_acc
# Out:
# 0.9739119035133718

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9737808075511274

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[1851,    3],
#        [  47,    6]])
